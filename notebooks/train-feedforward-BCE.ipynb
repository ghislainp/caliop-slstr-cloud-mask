# %%
import os
from glob import glob

import numpy as np
import pandas as pd
import xarray as xr

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

device = "cuda" if torch.cuda.is_available() else "cpu"

# %matplotlib widget
import matplotlib.pyplot as plt

# %%
cloud_dfN = pd.read_parquet("../data/caliop-slstr-greenland-maxsza80.parquet")
cloud_dfS = pd.read_parquet("../data/caliop-slstr-antarctic-maxsza80.parquet")


cloud_df = pd.concat((cloud_dfN, cloud_dfS))
print(len(cloud_df))
# Out:
# 1479720

# %%
cloud_df.columns
# Out:
# Index(['Latitude', 'Longitude', 'Profile_UTC_Time', 'IGBP_Surface_Type',
#        'Number_Layers_Found', 'geometry', 'S1', 'S2', 'S3', 'S4', 'S5', 'S7',
#        'S8', 'S9', 'bayes', 'cloud', 'confidence', 'latitude', 'longitude',
#        'pointing', 'satellite_azimuth_angle', 'satellite_zenith_angle',
#        'solar_azimuth_angle', 'solar_zenith_angle', 'file'],
#       dtype='object')

# %%
df= cloud_df

cloud = df['Number_Layers_Found'] > 0

#plt.figure()
print("could proportion:", cloud.mean())
plt.figure()
plt.plot(df.S5, df.S4, '.', markersize=1, alpha=0.1)
plt.plot(df.S5[~cloud], df.S4[~cloud], '.', markersize=3, alpha=0.1)
#plt.plot(df.S5[cloud], df.S4[cloud], '.', markersize=3, alpha=0.1)

plt.figure()
plt.plot(df.S8, df.S4, '.', markersize=1, alpha=0.1)
plt.plot(df.S8[~cloud], df.S4[~cloud], '.', markersize=3, alpha=0.1)
#plt.plot(df.S8[cloud], df.S4[cloud], '.', markersize=3, alpha=0.1)
# Out:
# could proportion: 0.47275971129673183
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
inputs = ['S1', 'S2', 'S3', 'S4', 'S5', 'S7_std', 'S8_std', 'S9_std', 'vza_std', 'sza_std', 'aa_std']



class CloudDataset(Dataset):
    def __init__(self, cloud_data):
        self.data = cloud_data.copy()
        self.data['S7_std'] = (self.data['S7'] - 200) / 73
        self.data['S8_std'] = (self.data['S8'] - 200) / 73
        self.data['S9_std'] = (self.data['S9'] - 200) / 73
        
        self.data['vza_std'] = self.data['satellite_zenith_angle'] / 90
        self.data['sza_std'] = self.data['solar_zenith_angle'] / 90
        self.data['aa_std'] = ((self.data['satellite_azimuth_angle'] - self.data['solar_azimuth_angle']) % 360) / 360

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        
        data = self.data.iloc[idx]
        
        #'Latitude', 'Longitude', 'Profile_UTC_Time', 'IGBP_Surface_Type',
        #'Number_Layers_Found', 'geometry', 'S1', 'S2', 'S3', 'S4', 'S5', 'S7',
        #'S8', 'S9', 'bayes', 'cloud', 'confidence', 'latitude', 'longitude',
        #'pointing', 'satellite_azimuth_angle', 'satellite_zenith_angle',
        #'solar_azimuth_angle', 'solar_zenith_angle'],
        
        cloud = float(data['Number_Layers_Found'] > 0)

        data = data[inputs].values.astype(np.float32)
        data = np.minimum(data, 1.3)
        return data - 0.5, np.array([cloud])   #np.array([cloud, 1 - cloud])

    # Define model
class NeuralNetwork2(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(len(inputs), 32),
            nn.LeakyReLU(),
            nn.Linear(32, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork2().to(device)
print(model)
# Out:
# NeuralNetwork2(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
#loss_fn =  nn.L1Loss()

# Pour model1:
#loss_fn = nn.CrossEntropyLoss()

# Pour model2:
loss_fn = nn.BCEWithLogitsLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    print("size=", size)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 1000 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            
            
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            
            # correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    # correct /= size
    # print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    print(f"Test Error: \n Avg loss: {test_loss:>8f} \n")

    
def errors(dataloader, model, loss_fn, threshold=0.5):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    
    good_detected_cloud = 0
    wrong_detected_cloud = 0
    
    good_detected_clear = 0
    wrong_detected_clear = 0
    is_cloud = 0
    is_not_cloud = 0
    
    if isinstance(threshold, np.ndarray):
        threshold = torch.from_numpy(threshold[np.newaxis, :])
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            
            cloud_detected = pred[:, 0][:, None] > threshold
            clear_detected = pred[:, 0][:, None] < threshold
            
            good_detected_cloud += torch.sum(cloud_detected & (y[:, 0][:, None] == 1), axis=0)
            wrong_detected_cloud += torch.sum(cloud_detected & (y[:, 0][:, None] == 0), axis=0)
            
            good_detected_clear += torch.sum(clear_detected & (y[:, 0][:, None] == 0), axis=0)
            wrong_detected_clear += torch.sum(clear_detected & (y[:, 0][:, None] == 1), axis=0)
            
            is_cloud += torch.sum(y[:, 0] == 1, axis=0)
            is_not_cloud += torch.sum(y[:, 0] == 0, axis=0)
    
    return pd.DataFrame({'TPR': good_detected_cloud / is_cloud, 
                         'FPR': wrong_detected_cloud / is_not_cloud,
                         'TPR_clear': good_detected_clear / is_not_cloud,
                         'FPR_clear': wrong_detected_clear / is_cloud})
    

    
training_size = len(cloud_df) // 2
test_size = training_size

batch_size = 10

train_dataloader = DataLoader(CloudDataset(cloud_df[:training_size]), batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(CloudDataset(cloud_df[-test_size:]), batch_size=batch_size, shuffle=False)

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")

#['S1', 'S2', 'S3', 'S4', 'S5', 'S8_std', 'S9_std', 'vza_std', 'sza_std', 'aa_std']
# Out:
# Epoch 1
# -------------------------------
# size= 739860
# loss: 0.681100  [    0/739860]
# loss: 0.254701  [10000/739860]
# loss: 0.352094  [20000/739860]
# loss: 0.477544  [30000/739860]
# loss: 0.353847  [40000/739860]
# loss: 0.416050  [50000/739860]
# loss: 0.317882  [60000/739860]
# loss: 0.153670  [70000/739860]
# loss: 0.477161  [80000/739860]
# loss: 0.138982  [90000/739860]
# loss: 0.591060  [100000/739860]
# loss: 0.577189  [110000/739860]
# loss: 0.561080  [120000/739860]
# loss: 0.147044  [130000/739860]
# loss: 0.154762  [140000/739860]
# loss: 0.256243  [150000/739860]
# loss: 0.501861  [160000/739860]
# loss: 0.328250  [170000/739860]
# loss: 0.119245  [180000/739860]
# loss: 0.104101  [190000/739860]
# loss: 0.196573  [200000/739860]
# loss: 0.083968  [210000/739860]
# loss: 0.329109  [220000/739860]
# loss: 0.116571  [230000/739860]
# loss: 0.385094  [240000/739860]
# loss: 0.357420  [250000/739860]
# loss: 0.169364  [260000/739860]
# loss: 0.241753  [270000/739860]
# loss: 0.455998  [280000/739860]
# loss: 0.188737  [290000/739860]
# loss: 0.390767  [300000/739860]
# loss: 0.152193  [310000/739860]
# loss: 0.612669  [320000/739860]
# loss: 0.090109  [330000/739860]
# loss: 0.081418  [340000/739860]
# loss: 0.500861  [350000/739860]
# loss: 0.743739  [360000/739860]
# loss: 0.082268  [370000/739860]
# loss: 0.577852  [380000/739860]
# loss: 0.307601  [390000/739860]
# loss: 0.901014  [400000/739860]
# loss: 0.358319  [410000/739860]
# loss: 0.825145  [420000/739860]
# loss: 0.084509  [430000/739860]
# loss: 0.427812  [440000/739860]
# loss: 0.465785  [450000/739860]
# loss: 0.170976  [460000/739860]
# loss: 0.082761  [470000/739860]
# loss: 0.314274  [480000/739860]
# loss: 0.329714  [490000/739860]
# loss: 0.321200  [500000/739860]
# loss: 0.354408  [510000/739860]
# loss: 0.259393  [520000/739860]
# loss: 0.085128  [530000/739860]
# loss: 0.101054  [540000/739860]
# loss: 0.213273  [550000/739860]
# loss: 0.390492  [560000/739860]
# loss: 0.360166  [570000/739860]
# loss: 0.034815  [580000/739860]
# loss: 0.303692  [590000/739860]
# loss: 0.297840  [600000/739860]
# loss: 0.209398  [610000/739860]
# loss: 0.134945  [620000/739860]
# loss: 0.059464  [630000/739860]
# loss: 0.424342  [640000/739860]
# loss: 0.077654  [650000/739860]
# loss: 0.315292  [660000/739860]
# loss: 0.557782  [670000/739860]
# loss: 0.203563  [680000/739860]
# loss: 0.158496  [690000/739860]
# loss: 0.777733  [700000/739860]
# loss: 0.109457  [710000/739860]
# loss: 0.127473  [720000/739860]
# loss: 0.229229  [730000/739860]
# Test Error:
#  Avg loss: 0.271485
#
# Epoch 2
# -------------------------------
# size= 739860
# loss: 0.164764  [    0/739860]
# loss: 0.030054  [10000/739860]
# loss: 0.419251  [20000/739860]
# loss: 0.547463  [30000/739860]
# loss: 0.362994  [40000/739860]
# loss: 0.038016  [50000/739860]
# loss: 0.119459  [60000/739860]
# loss: 0.346408  [70000/739860]
# loss: 0.275997  [80000/739860]
# loss: 0.438244  [90000/739860]
# loss: 0.153230  [100000/739860]
# loss: 0.038907  [110000/739860]
# loss: 0.195687  [120000/739860]
# loss: 0.543753  [130000/739860]
# loss: 0.169679  [140000/739860]
# loss: 0.508421  [150000/739860]
# loss: 0.084490  [160000/739860]
# loss: 0.153102  [170000/739860]
# loss: 0.343587  [180000/739860]
# loss: 0.175769  [190000/739860]
# loss: 0.075356  [200000/739860]
# loss: 0.083503  [210000/739860]
# loss: 0.083246  [220000/739860]
# loss: 0.212078  [230000/739860]
# loss: 0.516445  [240000/739860]
# loss: 0.161818  [250000/739860]
# loss: 0.046152  [260000/739860]
# loss: 0.190165  [270000/739860]
# loss: 0.134602  [280000/739860]
# loss: 0.139000  [290000/739860]
# loss: 0.233588  [300000/739860]
# loss: 0.300713  [310000/739860]
# loss: 0.126683  [320000/739860]
# loss: 0.124656  [330000/739860]
# loss: 0.318059  [340000/739860]
# loss: 0.423319  [350000/739860]
# loss: 0.133070  [360000/739860]
# loss: 0.160995  [370000/739860]
# loss: 0.302718  [380000/739860]
# loss: 0.044019  [390000/739860]
# loss: 0.190780  [400000/739860]
# loss: 0.300528  [410000/739860]
# loss: 0.522132  [420000/739860]
# loss: 0.222517  [430000/739860]
# loss: 0.159070  [440000/739860]
# loss: 0.169325  [450000/739860]
# loss: 0.115760  [460000/739860]
# loss: 0.076846  [470000/739860]
# loss: 0.484258  [480000/739860]
# loss: 0.789663  [490000/739860]
# loss: 0.568603  [500000/739860]
# loss: 0.096469  [510000/739860]
# loss: 0.066572  [520000/739860]
# loss: 0.214548  [530000/739860]
# loss: 0.076995  [540000/739860]
# loss: 0.214972  [550000/739860]
# loss: 0.038416  [560000/739860]
# loss: 0.247571  [570000/739860]
# loss: 0.628236  [580000/739860]
# loss: 0.241672  [590000/739860]
# loss: 0.449176  [600000/739860]
# loss: 0.055480  [610000/739860]
# loss: 0.142836  [620000/739860]
# loss: 0.495957  [630000/739860]
# loss: 0.692375  [640000/739860]
# loss: 0.267855  [650000/739860]
# loss: 0.405111  [660000/739860]
# loss: 0.556911  [670000/739860]
# loss: 0.207175  [680000/739860]
# loss: 0.279825  [690000/739860]
# loss: 0.210264  [700000/739860]
# loss: 0.135249  [710000/739860]
# loss: 0.156936  [720000/739860]
# loss: 0.138125  [730000/739860]
# Test Error:
#  Avg loss: 0.277528
#
# Epoch 3
# -------------------------------
# size= 739860
# loss: 0.230404  [    0/739860]
# loss: 0.323351  [10000/739860]
# loss: 0.110074  [20000/739860]
# loss: 0.248389  [30000/739860]
# loss: 0.065521  [40000/739860]
# loss: 0.105396  [50000/739860]
# loss: 0.102463  [60000/739860]
# loss: 0.106510  [70000/739860]
# loss: 0.220426  [80000/739860]
# loss: 0.491792  [90000/739860]
# loss: 0.081528  [100000/739860]
# loss: 0.045988  [110000/739860]
# loss: 0.539006  [120000/739860]
# loss: 0.149881  [130000/739860]
# loss: 0.265519  [140000/739860]
# loss: 0.283533  [150000/739860]
# loss: 0.229141  [160000/739860]
# loss: 0.234155  [170000/739860]
# loss: 0.107838  [180000/739860]
# loss: 0.168817  [190000/739860]
# loss: 0.092110  [200000/739860]
# loss: 0.428927  [210000/739860]
# loss: 0.142258  [220000/739860]
# loss: 0.103041  [230000/739860]
# loss: 0.086359  [240000/739860]
# loss: 0.562865  [250000/739860]
# loss: 0.367865  [260000/739860]
# loss: 0.355034  [270000/739860]
# loss: 0.242001  [280000/739860]
# loss: 0.162638  [290000/739860]
# loss: 0.328557  [300000/739860]
# loss: 0.351752  [310000/739860]
# loss: 0.630779  [320000/739860]
# loss: 0.045807  [330000/739860]
# loss: 0.592119  [340000/739860]
# loss: 0.288337  [350000/739860]
# loss: 0.045530  [360000/739860]
# loss: 0.138025  [370000/739860]
# loss: 0.541654  [380000/739860]
# loss: 0.135889  [390000/739860]
# loss: 0.324378  [400000/739860]
# loss: 0.121398  [410000/739860]
# loss: 0.179999  [420000/739860]
# loss: 0.244785  [430000/739860]
# loss: 0.595001  [440000/739860]
# loss: 0.396584  [450000/739860]
# loss: 0.077626  [460000/739860]
# loss: 0.527644  [470000/739860]
# loss: 0.426923  [480000/739860]
# loss: 0.804949  [490000/739860]
# loss: 0.160423  [500000/739860]
# loss: 0.365791  [510000/739860]
# loss: 0.466407  [520000/739860]
# loss: 0.085456  [530000/739860]
# loss: 0.089168  [540000/739860]
# loss: 0.322147  [550000/739860]
# loss: 0.072755  [560000/739860]
# loss: 0.141403  [570000/739860]
# loss: 0.168103  [580000/739860]
# loss: 0.300913  [590000/739860]
# loss: 0.441854  [600000/739860]
# loss: 0.077286  [610000/739860]
# loss: 0.387421  [620000/739860]
# loss: 0.228748  [630000/739860]
# loss: 0.255631  [640000/739860]
# loss: 0.144722  [650000/739860]
# loss: 0.144256  [660000/739860]
# loss: 0.152863  [670000/739860]
# loss: 0.291344  [680000/739860]
# loss: 0.484917  [690000/739860]
# loss: 0.664213  [700000/739860]
# loss: 0.095659  [710000/739860]
# loss: 0.069574  [720000/739860]
# loss: 0.183061  [730000/739860]
# Test Error:
#  Avg loss: 0.266669
#
# Epoch 4
# -------------------------------
# size= 739860
# loss: 0.061491  [    0/739860]
# loss: 0.238096  [10000/739860]
# loss: 0.732327  [20000/739860]
# loss: 0.045573  [30000/739860]
# loss: 0.312582  [40000/739860]
# loss: 0.490313  [50000/739860]
# loss: 0.222374  [60000/739860]
# loss: 0.225099  [70000/739860]
# loss: 0.461273  [80000/739860]
# loss: 0.332296  [90000/739860]
# loss: 0.245988  [100000/739860]
# loss: 0.107028  [110000/739860]
# loss: 0.302286  [120000/739860]
# loss: 0.293802  [130000/739860]
# loss: 0.240620  [140000/739860]
# loss: 0.340112  [150000/739860]
# loss: 0.117977  [160000/739860]
# loss: 0.511762  [170000/739860]
# loss: 0.674785  [180000/739860]
# loss: 0.532881  [190000/739860]
# loss: 0.197387  [200000/739860]
# loss: 0.206590  [210000/739860]
# loss: 0.222303  [220000/739860]
# loss: 0.044032  [230000/739860]
# loss: 0.333053  [240000/739860]
# loss: 0.577970  [250000/739860]
# loss: 0.112948  [260000/739860]
# loss: 0.261046  [270000/739860]
# loss: 0.271515  [280000/739860]
# loss: 0.084543  [290000/739860]
# loss: 0.057998  [300000/739860]
# loss: 0.178981  [310000/739860]
# loss: 0.670941  [320000/739860]
# loss: 0.190576  [330000/739860]
# loss: 0.252524  [340000/739860]
# loss: 0.189355  [350000/739860]
# loss: 0.269037  [360000/739860]
# loss: 0.297559  [370000/739860]
# loss: 0.200592  [380000/739860]
# loss: 0.268973  [390000/739860]
# loss: 0.490670  [400000/739860]
# loss: 0.270500  [410000/739860]
# loss: 0.129634  [420000/739860]
# loss: 0.122204  [430000/739860]
# loss: 0.078740  [440000/739860]
# loss: 0.347570  [450000/739860]
# loss: 0.197138  [460000/739860]
# loss: 0.138324  [470000/739860]
# loss: 0.051039  [480000/739860]
# loss: 0.179737  [490000/739860]
# loss: 0.583011  [500000/739860]
# loss: 0.228967  [510000/739860]
# loss: 0.094334  [520000/739860]
# loss: 0.035020  [530000/739860]
# loss: 0.303254  [540000/739860]
# loss: 0.481242  [550000/739860]
# loss: 0.148055  [560000/739860]
# loss: 0.413591  [570000/739860]
# loss: 0.058404  [580000/739860]
# loss: 0.039270  [590000/739860]
# loss: 0.206740  [600000/739860]
# loss: 0.050076  [610000/739860]
# loss: 0.113219  [620000/739860]
# loss: 0.048780  [630000/739860]
# loss: 0.189751  [640000/739860]
# loss: 0.545967  [650000/739860]
# loss: 0.528706  [660000/739860]
# loss: 0.275296  [670000/739860]
# loss: 0.530914  [680000/739860]
# loss: 0.292881  [690000/739860]
# loss: 0.843219  [700000/739860]
# loss: 0.397632  [710000/739860]
# loss: 0.259459  [720000/739860]
# loss: 0.533000  [730000/739860]
# Test Error:
#  Avg loss: 0.262200
#
# Epoch 5
# -------------------------------
# size= 739860
# loss: 0.142643  [    0/739860]
# loss: 0.508443  [10000/739860]
# loss: 0.243340  [20000/739860]
# loss: 0.407603  [30000/739860]
# loss: 0.158508  [40000/739860]
# loss: 0.148533  [50000/739860]
# loss: 0.080805  [60000/739860]
# loss: 0.461024  [70000/739860]
# loss: 0.417980  [80000/739860]
# loss: 0.185504  [90000/739860]
# loss: 0.472603  [100000/739860]
# loss: 0.226672  [110000/739860]
# loss: 0.168737  [120000/739860]
# loss: 0.071426  [130000/739860]
# loss: 0.172304  [140000/739860]
# loss: 0.385919  [150000/739860]
# loss: 0.349044  [160000/739860]
# loss: 0.285077  [170000/739860]
# loss: 0.200064  [180000/739860]
# loss: 0.127054  [190000/739860]
# loss: 0.177628  [200000/739860]
# loss: 0.142399  [210000/739860]
# loss: 0.558386  [220000/739860]
# loss: 0.120120  [230000/739860]
# loss: 0.458194  [240000/739860]
# loss: 0.130197  [250000/739860]
# loss: 0.186643  [260000/739860]
# loss: 0.513001  [270000/739860]
# loss: 0.313428  [280000/739860]
# loss: 0.541314  [290000/739860]
# loss: 0.077749  [300000/739860]
# loss: 0.210179  [310000/739860]
# loss: 0.132107  [320000/739860]
# loss: 0.146120  [330000/739860]
# loss: 0.190673  [340000/739860]
# loss: 0.339928  [350000/739860]
# loss: 0.188149  [360000/739860]
# loss: 0.117698  [370000/739860]
# loss: 0.093128  [380000/739860]
# loss: 0.721496  [390000/739860]
# loss: 0.122243  [400000/739860]
# loss: 0.335239  [410000/739860]
# loss: 0.116552  [420000/739860]
# loss: 0.825935  [430000/739860]
# loss: 0.225455  [440000/739860]
# loss: 0.082443  [450000/739860]
# loss: 0.368008  [460000/739860]
# loss: 0.181798  [470000/739860]
# loss: 0.168669  [480000/739860]
# loss: 0.246691  [490000/739860]
# loss: 0.135053  [500000/739860]
# loss: 0.084275  [510000/739860]
# loss: 0.195599  [520000/739860]
# loss: 0.307463  [530000/739860]
# loss: 0.120273  [540000/739860]
# loss: 0.245932  [550000/739860]
# loss: 0.053009  [560000/739860]
# loss: 0.063112  [570000/739860]
# loss: 0.055941  [580000/739860]
# loss: 0.098851  [590000/739860]
# loss: 0.242229  [600000/739860]
# loss: 0.139131  [610000/739860]
# loss: 0.112401  [620000/739860]
# loss: 0.615967  [630000/739860]
# loss: 0.735773  [640000/739860]
# loss: 0.257875  [650000/739860]
# loss: 0.390077  [660000/739860]
# loss: 0.103646  [670000/739860]
# loss: 0.347688  [680000/739860]
# loss: 0.103325  [690000/739860]
# loss: 0.349421  [700000/739860]
# loss: 0.131791  [710000/739860]
# loss: 0.160352  [720000/739860]
# loss: 0.212728  [730000/739860]
# Test Error:
#  Avg loss: 0.271776
#
# Done!

# %%
threshold = np.array(
            list(np.linspace(0, 0.1, 100)) +
            list(np.linspace(0.1, 0.8, 100)) +
            list(np.linspace(0.8, 0.98, 100)) +
            list(np.linspace(0.98, 1, 100))
            )

err = errors(test_dataloader, model, loss_fn, threshold=threshold)

# %%
err_ref = pd.read_csv("Errors/err-reference0.csv")

plt.figure()
plt.plot(err.FPR, err.TPR, '-', label='NN')
plt.plot(err_ref.FPR, err_ref.TPR, '-k', label='NN Ref')

plt.plot(0.122289, 0.809558, 's', label="SCDA")
plt.grid(alpha=0.2)
plt.legend()
plt.xlabel("False positive")
plt.ylabel("True positive")
plt.title("Cloud detection")
# Out:
# Text(0.5, 1.0, 'Cloud detection')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
